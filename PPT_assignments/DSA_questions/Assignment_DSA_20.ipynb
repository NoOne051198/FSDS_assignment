# %% [markdown]
# # Assignment - 20

# %% [markdown]
# <font size="3">__1. Given a binary tree, your task is to find subtree with maximum sum in tree.__</font><br>
#
# **Examples:**
#
# Input1 :
#
#        1
#
#      /   \
#
#    2      3
#
#   / \    / \
#
# 4   5  6   7
#
# Output1 : 28
#
# As all the tree elements are positive, the largest subtree sum is equal to sum of all tree elements.
#
# Input2 :
#
#        1
#
#      /    \
#
#   -2      3
#
#   / \    /  \
#
# 4   5  -6   2
#
# Output2 : 7
#
# Subtree with largest sum is :
#
#  -2
#
#  / \
#
# 4   5
#
# Also, entire tree sum is also 7.

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def maxSubtreeSum(root):
    def dfs(node):
        if not node:
            return 0

        left_sum = dfs(node.left)
        right_sum = dfs(node.right)

        # Calculate the sum of the subtree rooted at 'node'
        subtree_sum = left_sum + right_sum + node.val

        # Update the maximum sum if the current subtree has a larger sum
        nonlocal max_sum
        max_sum = max(max_sum, subtree_sum)

        # Return the sum of the current subtree rooted at 'node'
        return subtree_sum

    max_sum = float('-inf')
    dfs(root)
    return max_sum

# Example usage:
root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)
root.right.left = TreeNode(6)
root.right.right = TreeNode(7)

print(maxSubtreeSum(root))  # Output: 28
# Out:
# 28

# %% [markdown]
# <font size="3">__2. Construct the BST (Binary Search Tree) from its given level order traversal.__</font><br>
#
# **Example:**
#
# >Input: arr[] = {7, 4, 12, 3, 6, 8, 1, 5, 10}<br>
# Output: BST:
#
#             7
#
#          /    \
#
#        4     12
#
#      /  \     /
#
#     3   6  8
#
#    /    /     \
#
#  1    5      10

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def insert(root, val):
    if not root:
        return TreeNode(val)
    
    if val < root.val:
        root.left = insert(root.left, val)
    else:
        root.right = insert(root.right, val)

    return root

def constructBST(arr):
    if not arr:
        return None

    root = None
    for val in arr:
        root = insert(root, val)

    return root

def printTree(root, level=0, prefix="Root: "):
    if root:
        print(" " * (level * 4) + prefix + str(root.val))
        if root.left or root.right:
            printTree(root.left, level + 1, "L --- ")
            printTree(root.right, level + 1, "R --- ")

# Example usage:
arr = [7, 4, 12, 3, 6, 8, 1, 5, 10]
bst_root = constructBST(arr)
printTree(bst_root)
# Out:
# Root: 7
#     L --- 4
#         L --- 3
#             L --- 1
#         R --- 6
#             L --- 5
#     R --- 12
#         L --- 8
#             R --- 10

# %% [markdown]
# <font size="3">__3. Given an array of size n. The problem is to check whether the given array can represent the level order traversal of a Binary Search Tree or not.__</font><br>
#
# **Examples:**
#
# >Input1 : arr[] = {7, 4, 12, 3, 6, 8, 1, 5, 10}<br>
# Output1 : Yes
#
# For the given arr[], the Binary Search Tree is:
#
#             7
#
#          /    \
#
#        4     12
#
#      /  \     /
#
#     3   6  8
#
#    /    /     \
#
#  1    5      10
#
# >Input2 : arr[] = {11, 6, 13, 5, 12, 10}<br>
# Output2 : No
#
# The given arr[] does not represent the level order traversal of a BST.

# %%
def canRepresentBST(arr):
    n = len(arr)
    if n == 0:
        return True

    root = arr[0]
    i = 1

    while i < n and arr[i] < root:
        i += 1

    j = i
    while j < n and arr[j] > root:
        j += 1

    if j < n:
        return False

    left = canRepresentBST(arr[1:i])
    right = canRepresentBST(arr[i:])

    return left and right

# Examples:
arr1 = [7, 4, 12, 3, 6, 8, 1, 5, 10]
print(canRepresentBST(arr1))  # Output: True

arr2 = [11, 6, 13, 5, 12, 10]
print(canRepresentBST(arr2))  # Output: False
# Out:
# False
# False
